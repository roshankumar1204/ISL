# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Import libraries
import kagglehub
import shutil
import os

# Step 1: Download dataset (will go into Colab's Kaggle cache)
path = kagglehub.dataset_download("prasadshet/indian-sign-language-video-dataset")
print("Dataset cached at:", path)

# Step 2: Copy dataset from cache into Google Drive
src = path
dst = "/content/drive/MyDrive/kaggle_datasets/indian_sign_language"

# Create target directory if not exists
os.makedirs(dst, exist_ok=True)

# Copy files/folders recursivelygrfcedxwq
shutil.copytree(src, dst, dirs_exist_ok=True)

print("✅ Dataset copied to Google Drive at:", dst)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/prasadshet/indian-sign-language-video-dataset?dataset_version_number=1...
# 100%|██████████| 3.23G/3.23G [02:32<00:00, 22.7MB/s]
# Extracting files...
# Dataset cached at: /root/.cache/kagglehub/datasets/prasadshet/indian-sign-language-video-dataset/versions/1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3127127871.py in <cell line: 0>()
#      20
#      21 # Copy files/folders recursivelygrfcedxwq
# ---> 22 shutil.copytree(src, dst, dirs_exist_ok=True)
#      23
#      24 print("✅ Dataset copied to Google Drive at:", dst)
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     598     with os.scandir(src) as itr:
#     599         entries = list(itr)
# --> 600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     601                      ignore=ignore, copy_function=copy_function,
#     602                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# /usr/lib/python3.12/shutil.py in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     534                         copy_function(srcobj, dstname)
#     535             elif srcentry.is_dir():
# --> 536                 copytree(srcobj, dstname, symlinks, ignore, copy_function,
#     537                          ignore_dangling_symlinks, dirs_exist_ok)
#     538             else:
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     598     with os.scandir(src) as itr:
#     599         entries = list(itr)
# --> 600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     601                      ignore=ignore, copy_function=copy_function,
#     602                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# /usr/lib/python3.12/shutil.py in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     534                         copy_function(srcobj, dstname)
#     535             elif srcentry.is_dir():
# --> 536                 copytree(srcobj, dstname, symlinks, ignore, copy_function,
#     537                          ignore_dangling_symlinks, dirs_exist_ok)
#     538             else:
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     598     with os.scandir(src) as itr:
#     599         entries = list(itr)
# --> 600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     601                      ignore=ignore, copy_function=copy_function,
#     602                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# /usr/lib/python3.12/shutil.py in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     534                         copy_function(srcobj, dstname)
#     535             elif srcentry.is_dir():
# --> 536                 copytree(srcobj, dstname, symlinks, ignore, copy_function,
#     537                          ignore_dangling_symlinks, dirs_exist_ok)
#     538             else:
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     598     with os.scandir(src) as itr:
#     599         entries = list(itr)
# --> 600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     601                      ignore=ignore, copy_function=copy_function,
#     602                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# /usr/lib/python3.12/shutil.py in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     538             else:
#     539                 # Will raise a SpecialFileError for unsupported file types
# --> 540                 copy_function(srcobj, dstname)
#     541         # catch the Error from the recursive copytree so that we can
#     542         # continue with other files
#
# /usr/lib/python3.12/shutil.py in copy2(src, dst, follow_symlinks)
#     473                 raise
#     474
# --> 475     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     476     copystat(src, dst, follow_symlinks=follow_symlinks)
#     477     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     260         with open(src, 'rb') as fsrc:
#     261             try:
# --> 262                 with open(dst, 'wb') as fdst:
#     263                     # macOS
#     264                     if _HAS_FCOPYFILE:
#
# KeyboardInterrupt:

# %%
import os

# Path to your dataset inside Drive
base_path = "/content/drive/MyDrive/kaggle_datasets/indian_sign_language/Video_Dataset/Video_Dataset/"

# List all folders in the directory
all_folders = [f for f in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, f))]

# Print only the first 3

print("First 3 folders:")
for folder in all_folders[:5]:
    print(folder)
# Out:
# First 3 folders:
# Break
# Come
# Crocodile
# Cook
# Busy

# %%
import os
import random

# Base dataset path
DATA_PATH = "/content/drive/MyDrive/kaggle_datasets/indian_sign_language/Video_Dataset/Video_Dataset/"
# Get all available folders (words)
all_actions = [f for f in os.listdir(DATA_PATH) if os.path.isdir(os.path.join(DATA_PATH, f))]

# Pick any 3 randomly
actions = random.sample(all_actions, 5)

print("🔎 Total available words:", len(all_actions))
print("🎯 Selected words for training:", actions)

# Show number of videos inside each chosen folder
for action in actions:
    folder = os.path.join(DATA_PATH, action)
    print(f"📂 {action} → {len(os.listdir(folder))} videos")
# Out:
# 🔎 Total available words: 61
# 🎯 Selected words for training: ['Good Morning', 'Give', 'Crocodile', 'Maybe', 'Knife']
# 📂 Good Morning → 60 videos
# 📂 Give → 60 videos
# 📂 Crocodile → 60 videos
# 📂 Maybe → 60 videos
# 📂 Knife → 60 videos

# %%
# !pip install mediapipe opencv-python-headless
# Out:
# Requirement already satisfied: mediapipe in /usr/local/lib/python3.12/dist-packages (0.10.21)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (4.11.0.86)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.12/dist-packages (from mediapipe) (25.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.12/dist-packages (from mediapipe) (25.9.23)
# Requirement already satisfied: jax in /usr/local/lib/python3.12/dist-packages (from mediapipe) (0.5.3)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.12/dist-packages (from mediapipe) (0.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mediapipe) (3.10.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.12/dist-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.12/dist-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /usr/local/lib/python3.12/dist-packages (from mediapipe) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from mediapipe) (0.2.1)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.12/dist-packages (from sounddevice>=0.4.4->mediapipe) (2.0.0)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from jax->mediapipe) (0.5.3)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.12/dist-packages (from jax->mediapipe) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)

# %%
import cv2
import mediapipe as mp
import numpy as np

mp_holistic = mp.solutions.holistic

# Function to extract keypoints from one frame
def extract_keypoints_from_frame(results):
    pose, lh, rh = [], [], []

    # Pose (33 landmarks × 4 values = 132)
    if results.pose_landmarks:
        for lm in results.pose_landmarks.landmark:
            pose.extend([lm.x, lm.y, lm.z, lm.visibility])
    else:
        pose = [0] * 132

    # Left hand (21 landmarks × 3 values = 63)
    if results.left_hand_landmarks:
        for lm in results.left_hand_landmarks.landmark:
            lh.extend([lm.x, lm.y, lm.z])
    else:
        lh = [0] * 63

    # Right hand (21 landmarks × 3 values = 63)
    if results.right_hand_landmarks:
        for lm in results.right_hand_landmarks.landmark:
            rh.extend([lm.x, lm.y, lm.z])
    else:
        rh = [0] * 63

    return np.array(pose + lh + rh)  # shape = 258


# Function to convert video → sequence of keypoints
def video_to_keypoints(video_path, max_frames=30):
    cap = cv2.VideoCapture(video_path)
    sequence = []

    with mp_holistic.Holistic(min_detection_confidence=0.5,
                              min_tracking_confidence=0.5) as holistic:
        frame_count = 0
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            frame_count += 1

            # Convert BGR → RGB
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results = holistic.process(image)

            # Extract landmarks
            keypoints = extract_keypoints_from_frame(results)
            sequence.append(keypoints)

            # Stop if we reached max_frames
            if len(sequence) == max_frames:
                break

        cap.release()

    # Pad if sequence shorter
    if len(sequence) < max_frames:
        pad_length = max_frames - len(sequence)
        sequence.extend([np.zeros(sequence[0].shape)] * pad_length)

    print(f"📹 Processed {os.path.basename(video_path)} → {frame_count} frames → sequence shape {np.array(sequence).shape}")
    return np.array(sequence)

# %%
# test001

# Picking one sample video from first chosen action
sample_action = actions[0]
sample_video = os.listdir(os.path.join(DATA_PATH, sample_action))[0]
sample_path = os.path.join(DATA_PATH, sample_action, sample_video)

print("🔎 Testing extraction on:", sample_path)
sequence = video_to_keypoints(sample_path)

print("✅ Final sequence shape:", sequence.shape)  # should be (30, 258)
# Out:
# 🔎 Testing extraction on: /content/drive/MyDrive/kaggle_datasets/indian_sign_language/Video_Dataset/Video_Dataset/Good Morning/WIN_20231103_13_19_35_Pro.mp4
# 📹 Processed WIN_20231103_13_19_35_Pro.mp4 → 30 frames → sequence shape (30, 258)
# ✅ Final sequence shape: (30, 258)

# %%
import numpy as np

X, y = [], []

print("📂 Starting dataset creation...\n")
for idx, action in enumerate(actions):
    folder = os.path.join(DATA_PATH, action)
    videos = os.listdir(folder)
    print(f"▶ Processing class: {action} ({len(videos)} videos)")

    for i, video in enumerate(videos):  # ⚠️ for speed, limit to 10 videos first
        video_path = os.path.join(folder, video)
        sequence = video_to_keypoints(video_path)

        X.append(sequence)
        y.append(idx)

        print(f"   ✅ [{i+1}/{len(videos)}] {video} → saved")

print("\n🎯 Dataset creation complete.")
X = np.array(X)
y = np.array(y)

print("🔎 Final shapes:")
print("   X:", X.shape)   # (num_samples, 30, 258)
print("   y:", y.shape)   # (num_samples,)
# Out:
# 📂 Starting dataset creation...
#
# ▶ Processing class: Good Morning (60 videos)
# 📹 Processed WIN_20231103_13_19_35_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [1/60] WIN_20231103_13_19_35_Pro.mp4 → saved
# 📹 Processed WIN_20231103_13_49_57_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [2/60] WIN_20231103_13_49_57_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_17_37_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [3/60] WIN_20231103_13_17_37_Pro.mp4 → saved
# 📹 Processed WIN_20231103_13_18_31_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [4/60] WIN_20231103_13_18_31_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_20_43_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [5/60] WIN_20231103_13_20_43_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_18_31_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [6/60] WIN_20231103_13_18_31_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_17_04_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [7/60] WIN_20231103_13_17_04_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_50_22_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [8/60] WIN_20231103_13_50_22_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_20_36_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [9/60] WIN_20231103_13_20_36_Pro.mp4 → saved
# 📹 Processed WIN_20231103_13_18_44_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [10/60] WIN_20231103_13_18_44_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_50_03_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [11/60] WIN_20231103_13_50_03_Pro.mp4 → saved
# 📹 Processed WIN_20231103_13_17_43_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [12/60] WIN_20231103_13_17_43_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_17_43_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [13/60] WIN_20231103_13_17_43_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_18_31_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [14/60] WIN_20231103_13_18_31_Pro.mp4 → saved
# 📹 Processed WIN_20231103_13_17_24_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [15/60] WIN_20231103_13_17_24_Pro.mp4 → saved
# 📹 Processed WIN_20231103_13_50_22_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [16/60] WIN_20231103_13_50_22_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_18_18_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [17/60] WIN_20231103_13_18_18_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_17_49_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [18/60] WIN_20231103_13_17_49_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_17_24_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [19/60] WIN_20231103_13_17_24_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_20_27_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [20/60] WIN_20231103_13_20_27_Pro.mp4 → saved
# 📹 Processed WIN_20231103_13_20_36_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [21/60] WIN_20231103_13_20_36_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_50_28_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [22/60] WIN_20231103_13_50_28_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_18_25_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [23/60] WIN_20231103_13_18_25_Pro.mp4 → saved
# 📹 Processed WIN_20231103_13_20_43_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [24/60] WIN_20231103_13_20_43_Pro.mp4 → saved
# 📹 Processed WIN_20231103_13_20_43_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [25/60] WIN_20231103_13_20_43_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_49_57_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [26/60] WIN_20231103_13_49_57_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20231103_13_50_28_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [27/60] WIN_20231103_13_50_28_Pro.mp4 → saved
# 📹 Processed WIN_20231103_13_17_49_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [28/60] WIN_20231103_13_17_49_Pro.mp4 → saved
# 📹 Processed WIN_20231103_13
Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [32/60] WIN_20230831_12_41_03_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20230927_07_35_15_Pro_Trim_cropped_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [33/60] WIN_20230927_07_35_15_Pro_Trim_cropped_right_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_42_54_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [34/60] WIN_20230831_12_42_54_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_41_19_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [35/60] WIN_20230831_12_41_19_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_41_12_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [36/60] WIN_20230831_12_41_12_Pro.mp4 → saved
# 📹 Processed WIN_20230831_12_40_43_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [37/60] WIN_20230831_12_40_43_Pro.mp4 → saved
# 📹 Processed WIN_20230927_07_35_39_Pro_Trim_cropped_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [38/60] WIN_20230927_07_35_39_Pro_Trim_cropped_right_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_45_04_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [39/60] WIN_20230831_12_45_04_Pro.mp4 → saved
# 📹 Processed WIN_20230831_12_43_13_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [40/60] WIN_20230831_12_43_13_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_43_22_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [41/60] WIN_20230831_12_43_22_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_45_04_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [42/60] WIN_20230831_12_45_04_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_40_43_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [43/60] WIN_20230831_12_40_43_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_45_46_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [44/60] WIN_20230831_12_45_46_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_42_54_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [45/60] WIN_20230831_12_42_54_Pro.mp4 → saved
# 📹 Processed WIN_20230831_12_45_04_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [46/60] WIN_20230831_12_45_04_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_42_54_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [47/60] WIN_20230831_12_42_54_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_43_32_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [48/60] WIN_20230831_12_43_32_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20230927_07_35_01_Pro_Trim_cropped.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [49/60] WIN_20230927_07_35_01_Pro_Trim_cropped.mp4 → saved
# 📹 Processed WIN_20230831_12_40_52_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [50/60] WIN_20230831_12_40_52_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_40_43_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [51/60] WIN_20230831_12_40_43_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20230927_07_34_47_Pro_Trim_cropped.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [52/60] WIN_20230927_07_34_47_Pro_Trim_cropped.mp4 → saved
# 📹 Processed WIN_20230927_07_34_47_Pro_Trim_cropped_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [53/60] WIN_20230927_07_34_47_Pro_Trim_cropped_left_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_43_02_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [54/60] WIN_20230831_12_43_02_Pro.mp4 → saved
# 📹 Processed WIN_20230831_12_45_46_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [55/60] WIN_20230831_12_45_46_Pro_right_tilt.mp4 → saved
# 📹 Processed WIN_20230927_07_35_39_Pro_Trim_cropped_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [56/60] WIN_20230927_07_35_39_Pro_Trim_cropped_left_tilt.mp4 → saved
# 📹 Processed WIN_20230927_07_35_15_Pro_Trim_cropped_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [57/60] WIN_20230927_07_35_15_Pro_Trim_cropped_left_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_44_56_Pro_left_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [58/60] WIN_20230831_12_44_56_Pro_left_tilt.mp4 → saved
# 📹 Processed WIN_20230831_12_44_45_Pro.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [59/60] WIN_20230831_12_44_45_Pro.mp4 → saved
# 📹 Processed WIN_20230831_12_44_45_Pro_right_tilt.mp4 → 30 frames → sequence shape (30, 258)
#    ✅ [60/60] WIN_20230831_12_44_45_Pro_right_tilt.mp4 → saved
#
# 🎯 Dataset creation complete.
# 🔎 Final shapes:
#    X: (300, 30, 258)
#    y: (300,)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# One-hot encode labels
y_cat = tf.keras.utils.to_categorical(y, num_classes=len(actions))

print("🔎 Data ready for training:")
print("   X shape:", X.shape)     # (samples, 30, 258)
print("   y shape:", y_cat.shape) # (samples, num_classes)

# Define model
model = Sequential([
    LSTM(64, return_sequences=True, activation='relu', input_shape=(X.shape[1], X.shape[2])),
    LSTM(128, return_sequences=False, activation='relu'),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dense(len(actions), activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

print("\n📊 Model Summary:")
model.summary()

# Train model
history = model.fit(
    X, y_cat,
    epochs=20,
    batch_size=8,
    validation_split=0.2,
    verbose=1
)

print("\n✅ Training complete!")

model.save("/content/drive/MyDrive/isl_models/isl_sign_model.h5")
# Out:
# 🔎 Data ready for training:
#    X shape: (300, 30, 258)
#    y shape: (300, 5)
#
# 📊 Model Summary:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 30, 64)         │        82,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 190,085 (742.52 KB)
#  Trainable params: 190,085 (742.52 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.2144 - loss: 1.5883 - val_accuracy: 0.0000e+00 - val_loss: 2.2571
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2412 - loss: 1.4740 - val_accuracy: 0.0000e+00 - val_loss: 3.5281
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2850 - loss: 1.4164 - val_accuracy: 0.0000e+00 - val_loss: 4.2330
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2924 - loss: 1.4056 - val_accuracy: 0.0000e+00 - val_loss: 3.0403
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2698 - loss: 1.4231 - val_accuracy: 0.0000e+00 - val_loss: 4.1722
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3270 - loss: 1.3609 - val_accuracy: 0.0000e+00 - val_loss: 3.2148
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3123 - loss: 1.3460 - val_accuracy: 0.0000e+00 - val_loss: 4.5760
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4277 - loss: 1.2330 - val_accuracy: 0.0000e+00 - val_loss: 5.7571
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3338 - loss: 1.2480 - val_accuracy: 0.0000e+00 - val_loss: 8.1845
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3898 - loss: 1.1874 - val_accuracy: 0.0000e+00 - val_loss: 3.8926
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4125 - loss: 1.2133 - val_accuracy: 0.0000e+00 - val_loss: 6.6046
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3672 - loss: 1.3369 - val_accuracy: 0.0000e+00 - val_loss: 4.6895
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4498 - loss: 1.1589 - val_accuracy: 0.0000e+00 - val_loss: 7.4639
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5073 - loss: 1.1853 - val_accuracy: 0.0000e+00 - val_loss: 5.9275
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4768 - loss: 1.1346 - val_accuracy: 0.0000e+00 - val_loss: 6.1355
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4010 - loss: 1.4079 - val_accuracy: 0.0000e+00 - val_loss: 4.9980
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4403 - loss: 1.1247 - val_accuracy: 0.0000e+00 - val_loss: 5.2282
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4965 - loss: 1.0331 - val_accuracy: 0.0000e+00 - val_loss: 5.5136
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4246 - loss: 1.0951 - val_accuracy: 0.0000e+00 - val_loss: 4.6220
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4442 - loss: 0.9800 - val_accuracy: 0.0000e+00 - val_loss: 5.5462
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Training complete!

# %%
# Pick a random video from one of the chosen classes1
import random

test_action = random.choice(actions)
test_video = random.choice(os.listdir(os.path.join(DATA_PATH, test_action)))
test_path = os.path.join(DATA_PATH, test_action, test_video)

print(f"🎥 Testing on: {test_video} (actual label: {test_action})")

# Extract sequence for this video
test_seq = video_to_keypoints(test_path)
test_seq = np.expand_dims(test_seq, axis=0)  # shape (1, 30, 258)

# Make prediction
prediction = model.predict(test_seq)
pred_label = actions[np.argmax(prediction)]

print("🔮 Model prediction:", pred_label)
print("📌 Actual label:", test_action)
print("📊 Prediction probabilities:", prediction)
# Out:
# 🎥 Testing on: WIN_20231103_11_02_45_Pro.mp4 (actual label: Give)
# 📹 Processed WIN_20231103_11_02_45_Pro.mp4 → 30 frames → sequence shape (30, 258)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 🔮 Model prediction: Good Morning
# 📌 Actual label: Give
# 📊 Prediction probabilities: [[4.5544663e-01 3.9418986e-01 3.1451690e-03 1.4721152e-01 6.8118848e-06]]

# %%
import matplotlib.pyplot as plt

# Plot Accuracy
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Model Accuracy")
plt.legend()
plt.show()

# Plot Loss
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Model Loss")
plt.legend()
plt.show()
